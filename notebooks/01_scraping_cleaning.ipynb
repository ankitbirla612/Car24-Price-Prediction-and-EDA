# %%
import bs4
from bs4 import BeautifulSoup
import requests
import re
import time
from datetime import datetime

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from selenium import webdriver
from mpl_toolkits.mplot3d import Axes3D

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\DELL\Desktop\room208\Ankit\Car_prize_forcasting\notebooks

# %%
#src\scraper.py
from car24.scraper import scrape_cars24_city

# %%
cities = {

    # "Hyderabad":
    # "https://www.cars24.com/buy-used-cars-hyderabad/?itm_source=Cars24Website&itm_medium=sticky_header",


    "Delhi":
    "https://www.cars24.com/buy-used-car?sort=P&storeCityId=2&pinId=110001",


    "Mumbai":
    "https://www.cars24.com/buy-used-car?sort=P&storeCityId=2378&pinId=400001",


    "Bangalore":
    "https://www.cars24.com/buy-used-car?sort=P&storeCityId=4709&pinId=560001",


    "Chennai":
    "https://www.cars24.com/buy-used-car?sort=P&storeCityId=5732&pinId=600001"
}

# %%
for city, url in cities.items():

    scrape_cars24_city(
        url=url,
        city_name=city
    )
# Out:
# Opening Delhi page...
# Delhi data saved successfully
# c:\Users\DELL\Desktop\room208\Ankit\Car_prize_forcasting\data\raw\cars24_Delhi.html
# Opening Mumbai page...
# Mumbai data saved successfully
# c:\Users\DELL\Desktop\room208\Ankit\Car_prize_forcasting\data\raw\cars24_Mumbai.html
# Opening Bangalore page...
# Bangalore data saved successfully
# c:\Users\DELL\Desktop\room208\Ankit\Car_prize_forcasting\data\raw\cars24_Bangalore.html
# Opening Chennai page...
# Chennai data saved successfully
# c:\Users\DELL\Desktop\room208\Ankit\Car_prize_forcasting\data\raw\cars24_Chennai.html
